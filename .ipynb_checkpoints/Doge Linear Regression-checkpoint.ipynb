# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

data = pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Meme Coin\Dogecoin.csv")
print(data)
data.head()
# Out:
#             Date      Open      High       Low     Close        Volume  \
# 0     14-06-2021  0.323903  0.336927  0.091273  0.327787  1.822191e+09
# 1     13-06-2021  0.312485  0.330026  0.307892  0.324382  1.484851e+09
# 2     12-06-2021  0.318893  0.319332  0.301804  0.312084  1.605634e+09
# 3     11-06-2021  0.326364  0.333223  0.311502  0.319359  1.834447e+09
# 4     10-06-2021  0.343339  0.344529  0.323278  0.326351  2.114011e+09
# ...          ...       ...       ...       ...       ...           ...
# 2734  19-12-2013  0.000395  0.001520  0.000328  0.001162  0.000000e+00
# 2735  18-12-2013  0.000267  0.000362  0.000205  0.000362  0.000000e+00
# 2736  17-12-2013  0.000207  0.000289  0.000116  0.000269  0.000000e+00
# 2737  16-12-2013  0.000299  0.000866  0.000150  0.000205  0.000000e+00
# 2738  15-12-2013  0.000559  0.000904  0.000290  0.000298  0.000000e+00
#
#         Market Cap
# 0     4.261938e+10
# 1     4.217219e+10
# 2     4.056906e+10
# 3     4.151047e+10
# 4     4.241476e+10
# ...            ...
# 2734  1.115034e+07
# 2735  3.188943e+06
# 2736  2.169688e+06
# 2737  1.509085e+06
# 2738  1.960300e+06
#
# [2739 rows x 7 columns]
#          Date      Open      High       Low     Close        Volume  \
# 0  14-06-2021  0.323903  0.336927  0.091273  0.327787  1.822191e+09
# 1  13-06-2021  0.312485  0.330026  0.307892  0.324382  1.484851e+09
# 2  12-06-2021  0.318893  0.319332  0.301804  0.312084  1.605634e+09
# 3  11-06-2021  0.326364  0.333223  0.311502  0.319359  1.834447e+09
# 4  10-06-2021  0.343339  0.344529  0.323278  0.326351  2.114011e+09
#
#      Market Cap
# 0  4.261938e+10
# 1  4.217219e+10
# 2  4.056906e+10
# 3  4.151047e+10
# 4  4.241476e+10

# %%
X = data['Close'].values
Y = data['Market Cap'].values

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(X)

numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

print(b1, b0)
# Out:
# 129639234519.37367 -24943736.604340553

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color='#58b970', label='Regression Line')

plt.scatter(X, Y, color='#ef5423', label='Scatter Plot')

plt.xlabel('Close')
plt.ylabel('Market Cap')
plt.legend()
plt.show()
