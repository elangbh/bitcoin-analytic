# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

data = pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Ethereum.csv")
print(data)
data.head()
# Out:
#             Date         Open         High          Low        Close  \
# 0     14-06-2021  2508.770462  2606.432929  2469.388144  2583.048966
# 1     13-06-2021  2372.690096  2547.367910  2312.640169  2508.391632
# 2     12-06-2021  2354.752218  2447.227868  2265.758003  2372.484454
# 3     11-06-2021  2472.858836  2495.414705  2326.869586  2353.768687
# 4     10-06-2021  2611.142652  2619.957793  2435.401567  2471.518675
# ...          ...          ...          ...          ...          ...
# 2134  11-08-2015     0.708087     1.131410     0.663235     1.067860
# 2135  10-08-2015     0.713989     0.729854     0.636546     0.708448
# 2136  09-08-2015     0.706136     0.879810     0.629191     0.701897
# 2137  08-08-2015     2.793760     2.798810     0.714725     0.753325
# 2138  07-08-2015     2.831620     3.536610     2.521120     2.772120
#
#             Volume    Market Cap
# 0     2.778349e+10  3.003900e+11
# 1     2.709295e+10  2.916739e+11
# 2     2.572436e+10  2.758389e+11
# 3     2.483256e+10  2.736314e+11
# 4     2.875363e+10  2.872870e+11
# ...            ...           ...
# 2134  1.463100e+06  6.456929e+07
# 2135  4.052830e+05  4.281836e+07
# 2136  5.321700e+05  4.239957e+07
# 2137  6.741880e+05  4.548689e+07
# 2138  1.643290e+05  1.666106e+08
#
# [2139 rows x 7 columns]
#          Date         Open         High          Low        Close  \
# 0  14-06-2021  2508.770462  2606.432929  2469.388144  2583.048966
# 1  13-06-2021  2372.690096  2547.367910  2312.640169  2508.391632
# 2  12-06-2021  2354.752218  2447.227868  2265.758003  2372.484454
# 3  11-06-2021  2472.858836  2495.414705  2326.869586  2353.768687
# 4  10-06-2021  2611.142652  2619.957793  2435.401567  2471.518675
#
#          Volume    Market Cap
# 0  2.778349e+10  3.003900e+11
# 1  2.709295e+10  2.916739e+11
# 2  2.572436e+10  2.758389e+11
# 3  2.483256e+10  2.736314e+11
# 4  2.875363e+10  2.872870e+11

# %%
X = data['Close'].values
Y = data['Market Cap'].values

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(X)

numer = 0
denom = 0
for i in range(m):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

print(b1, b0)
# Out:
# 114426001.53023008 -2274808116.761322

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color='#58b970', label='Regression Line')

plt.scatter(X, Y, color='#ef5423', label='Scatter Plot')

plt.xlabel('Close')
plt.ylabel('Market Cap')
plt.legend()
plt.show()
