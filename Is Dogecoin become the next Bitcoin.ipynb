# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
import matplotlib
from matplotlib.colors import LinearSegmentedColormap
# For reading stock data from yahoo
from pandas_datareader.data import DataReader

# For time stamps
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%d-%m-%Y')
btc=pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Bitcoin.csv",parse_dates=['Date'],index_col='Date', date_parser=dateparse)
btc = btc.iloc[::-1]
btc.tail(5)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-06-10  37389.515651  38334.325443  35847.593641  36702.599375
# 2021-06-11  36697.031293  37608.694293  36044.449911  37334.399526
# 2021-06-12  37340.142844  37408.925595  34728.190101  35552.517148
# 2021-06-13  35555.790140  39322.780212  34864.109940  39097.860897
# 2021-06-14  39016.970178  40978.364477  38757.284122  40536.068967
#
#                   Volume    Market Cap
# Date
# 2021-06-10  4.357603e+10  6.875094e+11
# 2021-06-11  3.869974e+10  6.993687e+11
# 2021-06-12  3.792423e+10  6.660182e+11
# 2021-06-13  4.066911e+10  7.324657e+11
# 2021-06-14  4.851313e+10  7.594427e+11

# %%
maxValue=btc[btc['Close']==max(btc.Close)]
print("Highiest value of bitcoin")
maxValue
# Out:
# Highiest value of bitcoin
#                    Open          High           Low        Close  \
# Date
# 2021-04-13  59890.01779  63742.283337  59869.956293  63503.45793
#
#                   Volume    Market Cap
# Date
# 2021-04-13  6.998345e+10  1.186364e+12

# %%
btc.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   2970.000000   2970.000000   2970.000000   2970.000000  2.970000e+03
# mean    6487.757054   6675.516682   6282.989221   6501.084885  1.071007e+10
# std    11058.185226  11409.466174  10651.307992  11074.664345  1.881033e+10
# min       68.504997     74.561096     65.526001     68.431000  0.000000e+00
# 25%      427.883995    434.684250    420.753258    428.683754  2.999112e+07
# 50%     1988.109985   2101.905029   1911.434998   2018.864990  8.604240e+08
# 75%     8368.639871   8599.800245   8183.189230   8373.222355  1.549157e+10
# max    63523.754869  64863.098908  62208.964366  63503.457930  3.509679e+11
#
#          Market Cap
# count  2.970000e+03
# mean   1.169012e+11
# std    2.066385e+11
# min    7.784112e+08
# 25%    6.280513e+09
# 50%    3.311395e+10
# 75%    1.481718e+11
# max    1.186364e+12

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2970 entries, 2013-04-28 to 2021-06-14
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Open        2970 non-null   float64
#  1   High        2970 non-null   float64
#  2   Low         2970 non-null   float64
#  3   Close       2970 non-null   float64
#  4   Volume      2970 non-null   float64
#  5   Market Cap  2970 non-null   float64
# dtypes: float64(6)
# memory usage: 162.4 KB

# %%
doge=pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Meme Coin\Dogecoin.csv",parse_dates=['Date'],index_col='Date', date_parser=dateparse)
doge = doge.iloc[::-1]
doge.tail(5)
# Out:
#                 Open      High       Low     Close        Volume    Market Cap
# Date
# 2021-06-10  0.343339  0.344529  0.323278  0.326351  2.114011e+09  4.241476e+10
# 2021-06-11  0.326364  0.333223  0.311502  0.319359  1.834447e+09  4.151047e+10
# 2021-06-12  0.318893  0.319332  0.301804  0.312084  1.605634e+09  4.056906e+10
# 2021-06-13  0.312485  0.330026  0.307892  0.324382  1.484851e+09  4.217219e+10
# 2021-06-14  0.323903  0.336927  0.091273  0.327787  1.822191e+09  4.261938e+10

# %%
maxValue=doge[doge['Close']==max(doge.Close)]
print("Highiest value of Dogecoin")
maxValue
# Out:
# Highiest value of Dogecoin
#                Open      High       Low     Close        Volume    Market Cap
# Date
# 2021-05-07  0.58111  0.731972  0.520174  0.684777  2.861508e+10  8.868082e+10

# %%
bit=pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Dead Coin\bitconnect.csv",parse_dates=['Date'],index_col='Date', date_parser=dateparse)
bit=bit.iloc[:,1:7]
bit = bit.iloc[::-1]
bit=bit.iloc[:1580]
bit18=bit[:609]
bit.tail(5)
# Out:
#             Open  High   Low  Close  Volume  Volume(BCC)
# Date
# 2021-05-16  2.40  2.48  2.14   2.25    0.00         0.00
# 2021-05-17  2.25  2.30  2.06   2.19    4.26         1.92
# 2021-05-18  2.19  2.50  2.18   2.32   18.81         8.01
# 2021-05-19  2.31  2.34  1.68   2.01    0.00         0.00
# 2021-05-20  2.01  2.28  1.91   2.19    0.00         0.00

# %%
maxValue=bit[bit['Close']==max(bit.Close)]
print("Highiest value of Bitconnect")
maxValue
# Out:
# Highiest value of Bitconnect
#               Open    High    Low   Close      Volume  Volume(BCC)
# Date
# 2017-12-31  413.53  470.86  407.8  463.31  41366100.0     94254.86

# %%
eth=pd.read_csv(r"C:\Users\Elank\Documents\Backup laptop\Semester 6\Pengantar Big Data\Dataset\Ethereum.csv",parse_dates=['Date'],index_col='Date', date_parser=dateparse)
eth = eth.iloc[::-1]
eth.tail(5)
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2021-06-10  2611.142652  2619.957793  2435.401567  2471.518675  2.875363e+10
# 2021-06-11  2472.858836  2495.414705  2326.869586  2353.768687  2.483256e+10
# 2021-06-12  2354.752218  2447.227868  2265.758003  2372.484454  2.572436e+10
# 2021-06-13  2372.690096  2547.367910  2312.640169  2508.391632  2.709295e+10
# 2021-06-14  2508.770462  2606.432929  2469.388144  2583.048966  2.778349e+10
#
#               Market Cap
# Date
# 2021-06-10  2.872870e+11
# 2021-06-11  2.736314e+11
# 2021-06-12  2.758389e+11
# 2021-06-13  2.916739e+11
# 2021-06-14  3.003900e+11

# %%
maxValue=eth[eth['Close']==max(eth.Close)]
print("Highiest value of Ethereum")
maxValue
# Out:
# Highiest value of Ethereum
#                    Open         High          Low        Close        Volume  \
# Date
# 2021-05-11  3948.271909  4178.208815  3783.889474  4168.701049  5.267974e+10
#
#               Market Cap
# Date
# 2021-05-11  4.828819e+11

# %%
def to2018(df):
    df18=equalize(df,bit)
    return df18.iloc[:len(bit18)]

def equalize(df,dfs):
    low=len(dfs)
    high=len(df)
    dff=high-low
    
    return df.iloc[dff:]

# %%
btc18=to2018(btc)
eth18=to2018(eth)
crypto=["Bitcoin 2018","Bitcoin","Ethereum 2018","Ethereum","Bitconnect 2018","Dogecoin"]
cryptoDf=[btc18,btc,eth18,eth,bit18,doge]
num_plots = 6
total_cols = 2
total_rows = 3
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    sns.set_context('paper', font_scale = 2)
    plot =  sns.lineplot(data=cryptoDf[i], x="Date", y="Close",color='#732C2C',palette ='coolwarm',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])

# %%
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    sns.set_context('paper', font_scale = 2)
    plot =  sns.lineplot(data=cryptoDf[i], x="Date", y="Volume",color='#732C2C',palette ='coolwarm',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])

# %%
for df in cryptoDf:
    df['Daily Return'] = df['Close'].pct_change()
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(14*total_cols, 7*total_rows), constrained_layout=True)
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    cryptoDf[i]['Daily Return'].plot(ax=axs[row][pos], legend=True,color='#732C2C', linestyle='--', marker='.')
    axs[row][pos].set_title(crypto[i])

# %%
fig, axs = plt.subplots(nrows=total_rows, ncols=total_cols,
                        figsize=(8*total_cols, 5*total_rows))
for i, var in enumerate(crypto):
    row = i//total_cols
    pos = i % total_cols
    plot =sns.distplot(cryptoDf[i]['Daily Return'], bins=100, color='#732C2C',ax=axs[row][pos])
    axs[row][pos].set_title(crypto[i])
    plt.ylabel('Daily Return')

plt.tight_layout()

# %%
closeDf18=pd.DataFrame()
closeDf18['btc']=btc18['Close']
closeDf18['eth']=eth18['Close']
closeDf18['bit']=bit18['Close']
returns18 = closeDf18.pct_change()
returns18.head()
# Out:
#                  btc       eth       bit
# Date
# 2017-02-16       NaN       NaN       NaN
# 2017-02-17  0.018269 -0.017607 -0.005974
# 2017-02-18  0.007847  0.010547  0.017230
# 2017-02-19 -0.006212 -0.004036 -0.035637
# 2017-02-20  0.030643 -0.025740  0.015868

# %%
btc=equalize(btc,eth)
doge=equalize(doge,eth)
closeDf=pd.DataFrame()
closeDf['btc']=btc['Close']
closeDf['eth']=eth['Close']
closeDf['doge']=doge['Close']
returns = closeDf.pct_change()
returns.head()
# Out:
#                  btc       eth      doge
# Date
# 2015-08-07       NaN       NaN       NaN
# 2015-08-08 -0.066484 -0.728250 -0.059557
# 2015-08-09  0.015655 -0.068268  0.022199
# 2015-08-10 -0.002313  0.009333 -0.010966
# 2015-08-11  0.022369  0.507323  0.022920

# %%
sns.jointplot(data=returns18, x='btc', y="bit", kind='scatter',color='#732C2C',height=8)
plt.show()

# %%
sns.jointplot(data=returns, x='btc', y="doge", kind='scatter',color='#732C2C',height=8)
plt.show()

# %%
def NonLinCdict(steps, hexcol_array):
    cdict = {'red': (), 'green': (), 'blue': ()}
    for s, hexcol in zip(steps, hexcol_array):
        rgb =matplotlib.colors.hex2color(hexcol)
        cdict['red'] = cdict['red'] + ((s, rgb[0], rgb[0]),)
        cdict['green'] = cdict['green'] + ((s, rgb[1], rgb[1]),)
        cdict['blue'] = cdict['blue'] + ((s, rgb[2], rgb[2]),)
    return cdict

hc = ['#F8EDED', '#EAC8C8', '#CF7F7F', '#BA4949', '#732C2C']
th = [0, 0.1, 0.5, 0.9, 1]

cdict = NonLinCdict(th, hc)
cm = LinearSegmentedColormap('test', cdict)
plt.figure(figsize=(10,6))
sns.heatmap(returns18.corr(), annot=True, cmap=cm)
plt.show()

# %%
rets = returns18.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='#732C2C', connectionstyle='arc3,rad=-0.3'))

# %%
rets = returns.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 7))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='#732C2C', connectionstyle='arc3,rad=-0.3'))
